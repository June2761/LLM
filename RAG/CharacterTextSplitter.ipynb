# %%
from langchain.document_loaders import UnstructuredFileLoader
from langchain.text_splitter import CharacterTextSplitter

splitter = CharacterTextSplitter(
    separator="\n",
    chunk_size=200,
    chunk_overlap=50
)

loader = UnstructuredFileLoader("/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf")

loader.load_and_split(text_splitter=splitter)
# Out:
# Created a chunk of size 298, which is longer than the specified 200
# Created a chunk of size 407, which is longer than the specified 200
# Created a chunk of size 253, which is longer than the specified 200
# Created a chunk of size 282, which is longer than the specified 200
# Created a chunk of size 243, which is longer than the specified 200
# Created a chunk of size 390, which is longer than the specified 200
# Created a chunk of size 341, which is longer than the specified 200
# Created a chunk of size 250, which is longer than the specified 200
# Created a chunk of size 245, which is longer than the specified 200
# Created a chunk of size 205, which is longer than the specified 200
# Created a chunk of size 202, which is longer than the specified 200
# Created a chunk of size 217, which is longer than the specified 200
# Created a chunk of size 273, which is longer than the specified 200
# Created a chunk of size 259, which is longer than the specified 200
# Created a chunk of size 246, which is longer than the specified 200
# Created a chunk of size 698, which is longer than the specified 200
# Created a chunk of size 348, which is longer than the specified 200
# Created a chunk of size 321, which is longer than the specified 200
# Created a chunk of size 413, which is longer than the specified 200
# Created a chunk of size 581, which is longer than the specified 200
# Created a chunk of size 766, which is longer than the specified 200
# Created a chunk of size 223, which is longer than the specified 200
# Created a chunk of size 321, which is longer than the specified 200
# Created a chunk of size 242, which is longer than the specified 200
# Created a chunk of size 325, which is longer than the specified 200
# Created a chunk of size 201, which is longer than the specified 200
# Created a chunk of size 220, which is longer than the specified 200
# Created a chunk of size 276, which is longer than the specified 200
# Created a chunk of size 276, which is longer than the specified 200
# Created a chunk of size 237, which is longer than the specified 200
# Created a chunk of size 444, which is longer than the specified 200
# [Document(page_content='Inspection Strategy 20: Erosion/Erosion-Corrosion\nVersion 1.8, July 26, 2017 Downstream & Chemicals – Manufacturing\nDescription of Damage', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='Erosion is the loss of metal from a surface caused by the relative motion of material abrading or impinging on the metal. Erosion-corrosion is the accelerated loss of metal from a surface caused by the removal of protective scales, allowing corrosion of the fresh metal that is continually exposed.', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='Failure Modes\nMost Likely\nLess Likely\nNot Applicable\nPinhole-sized leaks\nX\nSmall- to medium-sized leaks\nX\nThrough-wall cracks\nX\nLarge leak or rupture\nX\nAffected Materials\nPreferred Materials', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='X\nAffected Materials\nPreferred Materials\nAll materials\nHard-faced materials\nCorrosion-resistant alloys\nErosion-resistant refractory (catalyst service)\nCritical Factors\nSolids content\nVelocity', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='Critical Factors\nSolids content\nVelocity\nCorrosiveness of process stream\nMaterial composition\nAffected Units or Equipment\nAppearance\nEquipment exposed to moving corrosive fluids or solids\nFCC units', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='FCC units\nSmooth or scalloped areas with grooves, gullies, or wave patterns\nDirectional pattern\nCoker\nCrude units and vacuum systems\nSharp edges or features\nHydroprocessing units\nWet gas scrubber', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='Hydroprocessing units\nWet gas scrubber\nContinuous catalytic reformers', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='Inspection strategies and associated documents were developed using the latest industry information and practices, including API 571. The documents were initially drafted by third-party industry leaders, content was contributed by Chevron Manufacturing inspection experts, and the documents were reviewed by ETC Materials Engineers who added Chevron-specific information and provided final overall approval.', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='© 2015 – 2017 Chevron U.S.A. Inc. All rights reserved. Company Confidential – Uncontrolled When Printed\n1 of 14\nInspection Strategy 20: Erosion/Erosion-Corrosion Version 1.8, July 26, 2017', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='Downstream & Chemicals – Manufacturing\nInspection\nMonitoring\nRT\nManual UT scanning\nThickness monitoring sensors\nGrid UT\nAUT\nPrevention and Mitigation\nSusceptibility to Damage', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='Prevention and Mitigation\nSusceptibility to Damage\nReduction in Susceptibility\nRelated Mechanisms\nReferences\nImages and Charts\nVersion History', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='References\nImages and Charts\nVersion History\n© 2015 – 2017 Chevron U.S.A. Inc. All rights reserved. Company Confidential – Uncontrolled When Printed\n2 of 14', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='2 of 14\nInspection Strategy 20: Erosion/Erosion-Corrosion Version 1.8, July 26, 2017\nDownstream & Chemicals – Manufacturing\nAffected Materials', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='Affected Materials\nA. All materials, including refractories, can experience erosion or erosion-corrosion. Degree of', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='susceptibility depends on the combination of critical factors to which the material is exposed.', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='B. All material which experiences corrosion from the process stream that also contains flowing solid media is subject to erosion. Examples of this are catalyst erosion in fluidized catalytic cracking (FCC) and continuous catalytic reforming (CCR) units.', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='C. High velocities and turbulent flow cause erosion-corrosion even without solid media in the process flow. Carbon steel, low-alloy steels, and Cu-Ni alloys are susceptible to this. Examples of this are naphthenic acid in crude units and ammonium bisulfide in hydroprocessing units.', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='Critical Factors\nThe critical factors for erosion and erosion-corrosion are the solids content, velocity, corrosiveness of the process stream, and material composition.\nFactor\nDescription\nA.', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='Factor\nDescription\nA.\nSolids content', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='The solids content in the process fluid significantly impacts the degree of erosion and erosion-corrosion. Slurries (solids suspended in a liquid) with > 1% solids should be considered erosive.', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='Circulating solid catalyst systems are very erosive. The shape, hardness, and size of the catalyst affect erosion, but generally this is not something that is controlled. Larger particles are more damaging because of the higher kinetic energy.', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='B.\nVelocity', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='The corrosion resistance of many metals is dependent on the formation of protective films or scales. Increasing process stream velocities imparts higher energy on the metal surface (high wall shear stresses), which damages and removes the protective layers and exposes fresh metal to corrosion. High velocities and turbulent locations in the corrosive liquid flow promote erosion-corrosion.', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='General velocity limit guidelines are determined for each type of material and service combination and are grouped according to corrosive streams (with and without solids) and catalyst streams. Exceeding these limits may result in unacceptable corrosion rates. \uf02d Corrosive streams with no solids: Carbon steel components with stream velocity', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='< 15 fps (5 m/s), and corrosion-resistant alloy (CRA) components with stream velocity < 30 fps (9 m/s).\n\uf02d Corrosive streams with solids: All alloys with solids content < 1% and velocity < 7 fps', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='(2 m/s).\n\uf02d Noncorrosive streams with solids: All alloys with solids content < 1% and velocity\n< 10 fps (3 m/s).', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='< 10 fps (3 m/s).\n\uf02d High-velocity catalyst service: All non-hardfaced alloys with velocity < 50 fps (15 m/s).', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='Angle of impact strongly affects erosion by solids. In low-velocity laminar flow, impact angles of particles are mostly low and therefore have lower erosion rates. Turbulent flow results in a wide range of impact angles and greatly increased erosion.', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='C.\nCorrosiveness of process stream', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='With erosion-corrosion, the more aggressive the process fluid, the more rapid corrosion proceeds. Fresh exposed metal is particularly vulnerable because it often behaves as an anode to the adjacent metal that is still protected by film or scale.', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='Corrosive process fluids can attack protective layers and expose fresh metal to additional attack.\nA corrosive process stream is one that consumes the corrosion allowance in less than 10 years.', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='© 2015 – 2017 Chevron U.S.A. Inc. All rights reserved. Company Confidential – Uncontrolled When Printed\n3 of 14\nInspection Strategy 20: Erosion/Erosion-Corrosion Version 1.8, July 26, 2017', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='Downstream & Chemicals – Manufacturing\nFactor\nDescription\nD.\nMaterial composition\nAll materials, including refractories, exposed to flowing solid media are subject to erosion.', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='\uf02d Softer materials such as copper, copper alloys, and aluminum alloys are generally less resistant to erosion. Within a class of alloys, generally harder types resist pure erosion better than softer types.', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='\uf02d Hardfacing materials are more resistant to erosion than the commonly used materials\nof construction.', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='Corrosion-resistant materials reduce the rates of metal loss due to erosion-corrosion. When erosion exposes fresh metal, a corrosion-resistant alloy corrodes at a lower rate than a less-resistant metal.', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='\uf02d Harder materials, including hardfacings, are not necessarily more resistant to erosion- corrosion. As erosion continually exposes fresh metal to the process, the hardfacing may be vulnerable to high corrosion rates.', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='\uf02d Upgrading to an alloy that is corrosion-resistant helps mitigate the corrosion aspect of', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='the erosion-corrosion but may not eliminate metal loss completely if flowing solid media is still sufficient to cause erosion. An example of this is 300 series stainless steel, which is generally more corrosion-resistant than carbon steel but similar in erosion resistance.', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='Flow-accelerated corrosion is also considered erosion-corrosion. Carbon steel, low-alloy steels, and Cu-Ni alloys are susceptible to accelerated corrosion at high velocities and turbulent locations in some corrosive environments in the absence of solid media.', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='Affected Units or Equipment', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='A. Locations that create turbulence or disturb laminar flow are more vulnerable to erosion and erosion-corrosion than other areas. These locations are bends, elbows, tees, reducers, valves, measuring devices, and components installed in the pipe.', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='B. FCC units', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='The FCC unit experiences the most severe erosion in the refinery. The aluminum oxide catalysts erode components in the reactor and regenerator sections, including cyclones, distributors, diplegs, shed trays, and other internals. Any equipment that sees catalyst flow may be at risk. Flue gas piping as well as the fractionator bottoms system can be at risk if carryover of catalyst is occurring. Any associated piping, pumps, and valves that can create turbulence are subject to erosion. The high temperatures soften the metals, which exacerbates the erosion. Refractory is used to shield metal from the high temperatures of the process, but the insulating refractories are also eroded by catalyst.', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='C. Coker', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='Coke fines are extremely erosive. All piping with coke fine slurries is likely to experience erosion and erosion-corrosion. Piping from the heaters to the coke drums is most vulnerable. Furnace return bends and outlets are also known trouble areas. Erosion- corrosion can also be experienced in the fractionator bottoms piping and associated pumps.', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='D. Crude units and vacuum systems', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='Naphthenic acid erosion-corrosion occurs when processing crude that has a high total acid number (TAN). Sulfidation erosion-corrosion can also occur in crude and vacuum systems. Locations for this damage are in the furnace transfer lines and the piping and valves in the side cuts due to higher velocities in these lines.', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='© 2015 – 2017 Chevron U.S.A. Inc. All rights reserved. Company Confidential – Uncontrolled When Printed\n4 of 14\nInspection Strategy 20: Erosion/Erosion-Corrosion Version 1.8, July 26, 2017', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='Downstream & Chemicals – Manufacturing\nE. Hydroprocessing units', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='Reactor effluent piping in the exchanger and air cooler trains are subject to erosion- corrosion by ammonium bisulfide. The inlet and outlet piping of the reactor effluent air coolers (REACs) and cold high-pressure separator (CHPS) sour water outlet piping are the most common locations. Piping downstream of the pressure letdown valve is also an area of higher risk due to the large pressure drop and turbulence.', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='F. Wet gas scrubber\nSlurry circulation piping and piping components are vulnerable to erosion and erosion- corrosion.\nG. CCR units', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='G. CCR units\nThe areas that can experience erosion are catalyst transfer lines and areas with high pressure drop, particularly in the regeneration circuit.\nAppearance or Morphology of Damage', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='Appearance or Morphology of Damage\nA. Damage from erosion and erosion-corrosion has a distinctive appearance with many', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='scalloped or rounded areas. There may be groove, gulley, or wave patterns. Damage can also appear as sharp edges or features.', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='B. Damage usually exhibits a directional pattern that coincides with process flow.\nPrevention and Mitigation\nA. Use a harder material to decrease erosion.', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='The new material may be harder itself or have a hardfacing applied. Harder materials may have been heat-treated to increase hardness, or a surface hardening technique can be applied (boronizing, nitriding, etc.). Hardfacing is a metallic weld overlay, often cobalt- based. Chromium or tungsten carbides are also used. Hardfacings can be applied to carbon steel, low-alloy steel, stainless steel (SS), and nickel-based alloys. Nickel-based hardfacings are particularly good in corrosive atmospheres. Erosion-resistant refractories are used to resist erosion in hot catalyst systems.', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='B. Upgrade to corrosion-resistant material.', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='A more corrosion-resistant alloy in the service can mitigate the severity of the erosion- corrosion. Upgrading to a corrosion-resistant alloy reduces but does not eliminate all metal loss if solids are sufficient to cause continued erosion. If the erosion-corrosion is in a corrosive environment without solids, upgrading to a corrosion-resistant alloy should eliminate the erosion-corrosion. Carbon steel and 300 series SS have similar erosion resistance, but the stainless steel has better corrosion resistance in many process environments. Corrosion-resistant alloys with chromium, nickel, and molybdenum have increased resistance to flow-induced corrosion compared to carbon steel and 300 series SS, but the degree of resistance depends on the corrosive service.', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='C. Use corrosion inhibitor to help reduce corrosion of freshly exposed metal.', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='Whether to use inhibitors and which type to add depends on the process fluid and the alloy composition. However, the effectiveness of inhibitors decreases in high-velocity (> 10 fps, or 3 m/s) or highly turbulent locations.', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='© 2015 – 2017 Chevron U.S.A. Inc. All rights reserved. Company Confidential – Uncontrolled When Printed\n5 of 14\nInspection Strategy 20: Erosion/Erosion-Corrosion Version 1.8, July 26, 2017', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='Downstream & Chemicals – Manufacturing\nD. Alter the piping system design.', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='The shape and geometry of the piping system can be modified to mitigate erosion and erosion-corrosion by decreasing the abrasion and impingement on pipe walls. Larger radii bends and elbows promote more laminar flow. Larger diameter pipe decreases velocity. Cushion tees are often used to mitigate the effects of erosion.', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='Impingement plates or baffles may be added to absorb the energy from erosive streams.', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='The velocity can be maintained within specified limits to decrease the severity of erosion-corrosion. Higher velocities remove protective film and scales. Specific limits are determined by the process and the alloy composition in the service.', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='Inspection\nErosion/erosion-corrosion is categorized as localized corrosion. Erosion/erosion-corrosion affects turbulent areas and areas of direct impingement.\nA. Piping', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='A. Piping\nUse these recommended non-destructive examination (NDE) methods:\n\uf02d Radiographic testing (RT)\n\uf02d Manual ultrasonic testing (scanning or grid)\n\uf02d Automated ultrasonic testing (AUT)', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='\uf02d Automated ultrasonic testing (AUT)\nInspect the features listed in the following table:\nFeature Type1\nInspection Focus\nA\nAt ells, including up to 6 in. (15 cm) downstream.', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='At ells, including up to 6 in. (15 cm) downstream.\nThis feature type is expected to have higher corrosion due to particularly high velocity or turbulence.\nFeatures immediately downstream of:', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='Features immediately downstream of:\n\uf02d Pump discharges\n\uf02d Control or flow-throttling valve outlets (including bypasses)\n\uf02d Eductors\n\uf02d Orifice flanges\n\uf02d Internal protrusions\n\uf02d Mixers or strainers\nB', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='\uf02d Internal protrusions\n\uf02d Mixers or strainers\nB\nThe following features, including up to 6 in. (15 cm) downstream:', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='This feature type is also susceptible due to high velocity or turbulence and should be included in inspection.\n\uf02d Tees\n\uf02d Miter joints\n\uf02d Branch connections\n\uf02d Reducers\n\uf02d Expansion joints', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='\uf02d Branch connections\n\uf02d Reducers\n\uf02d Expansion joints\nAreas of known excessive internal weld reinforcement', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='1 In the case that a feature can be categorized as both Type A and Type B, it shall be considered a Type A feature.\nB. Pressure Vessels\nTBD\nC. Heat Exchangers', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='B. Pressure Vessels\nTBD\nC. Heat Exchangers\n© 2015 – 2017 Chevron U.S.A. Inc. All rights reserved. Company Confidential – Uncontrolled When Printed\n6 of 14', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='6 of 14\nInspection Strategy 20: Erosion/Erosion-Corrosion Version 1.8, July 26, 2017\nDownstream & Chemicals – Manufacturing\nTBD\nD. Furnaces\nTBD\nE. Deadlegs', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='Deadlegs are no more susceptible to erosion/erosion-corrosion than other areas. To inspect deadlegs subject to erosion/erosion-corrosion, use the inspection guidance under “Piping” in this section.', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='Monitoring\nA. Monitor thicknesses of vulnerable or suspect locations with permanently mounted UT', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='sensors. This includes sections of high velocity or high-solids loading, particularly in more vulnerable locations such as bends, elbows, and valves.', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='© 2015 – 2017 Chevron U.S.A. Inc. All rights reserved. Company Confidential – Uncontrolled When Printed\n7 of 14\nInspection Strategy 20: Erosion/Erosion-Corrosion Version 1.8, July 26, 2017', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='Downstream & Chemicals – Manufacturing\nSusceptibility to Damage\nPiping\n\uf083 Higher\nSusceptibility Levels\nLower \uf084\n1\n2\n3\n4\n5\n6\nCorrosive Process Streams1,2', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='Lower \uf084\n1\n2\n3\n4\n5\n6\nCorrosive Process Streams1,2\nCarbon steel with no solids in stream velocity ≥ 15 fps (5 m/s)\nCarbon steel with no solids in stream 10 fps (3 m/s) ≤ velocity < 15 fps (5 m/s)', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='Carbon steel with no solids in stream 5 fps (1.5 m/s) ≤ velocity < 10 fps (3 m/s)\nCRA (300 series SS or Ni-Cr alloys) with no solids in stream velocity ≥ 30 fps (9 m/s)', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='CRA (300 series SS or Ni-Cr alloys) with no solids in stream 15 fps (5 m/s) ≤ velocity < 30 fps (9 m/s)\nCarbon steel with\nCarbon steel with\nsolids content > 1%, velocity ≥ 7 fps (2 m/s)', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='solids content > 1%, velocity ≥ 7 fps (2 m/s)\nsolids content > 1%, 3 fps (1 m/s) ≤ velocity < 7 fps (2 m/s)\nCRA (300 series SS or Ni-Cr alloys) with solids content > 1%, velocity ≥ 7 fps (2 m/s)', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='CRA (300 series SS or Ni-Cr alloys) with solids content > 1%, 3 fps (1 m/s) ≤ velocity < 7 fps (2 m/s)\nNoncorrosive Streams\nSolids content ≥ 1%, velocity ≥ 10 fps (3 m/s)', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='Solids content ≥ 1%, velocity ≥ 10 fps (3 m/s)\nSolids content ≥ 1%, 5 fps (1.5 m/s) ≤ velocity < 10 fps (3 m/s)\n0.1 ≤ solids content < 1%, 5 fps (1.5 m/s) ≤ velocity < 20 fps (9 m/s)', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='Solids content < 0.1% with velocity ≥ 20 fps (9 m/s)\nSolids content < 0.1% with 10 fps (3 m/s) ≤ velocity < 20 fps (9 m/s)\nHard-faced material in stream with solids content ≥ 1%', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='Hard-faced material in stream with solids content < 1%\n© 2015 – 2017 Chevron U.S.A. Inc. All rights reserved. Company Confidential – Uncontrolled When Printed\n8 of 14', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='8 of 14\nInspection Strategy 20: Erosion/Erosion-Corrosion Version 1.8, July 26, 2017\nDownstream & Chemicals – Manufacturing\n\uf083 Higher\nSusceptibility Levels\nLower \uf084\n1\n2\n3\n4\n5\n6', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='\uf083 Higher\nSusceptibility Levels\nLower \uf084\n1\n2\n3\n4\n5\n6\nCatalyst Service Without Erosion-Resistant Refractory\n≥ 50 fps (15 m/s)\n25 fps (6 m/s) ≤\nvelocity < 50 fps (15 m/s)\n10 fps (3 m/s) ≤', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='velocity < 50 fps (15 m/s)\n10 fps (3 m/s) ≤\n2 fps (0.6 m/s) ≤ velocity < 10 fps (3 m/s)\n2 fps (0.6 m/s) ≤ velocity < 10 fps (3 m/s)', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='Note: This table provides general guidelines, but susceptibility level is highly dependent on specific environment. 1 A corrosive process stream is one that consumes the corrosion allowance in less than 10 years. 2 If solids content is between 0% and 1% for corrosive process, assume 1% when determining susceptibility level.', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='© 2015 – 2017 Chevron U.S.A. Inc. All rights reserved. Company Confidential – Uncontrolled When Printed\n9 of 14\nInspection Strategy 20: Erosion/Erosion-Corrosion Version 1.8, July 26, 2017', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='Downstream & Chemicals – Manufacturing\nReduction in Susceptibility\nPiping\nSusceptibility level can be lowered by applying the following tasks:\nMitigation Task\nLower susceptibility by:', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='Mitigation Task\nLower susceptibility by:\nAdd velocity-imposed IOW to specified limits\nOne level\nAdd corrosion inhibitor in corrosive process stream with velocity < 15 fps (5 m/s)\nOne level', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='One level\nApply erosion-resistant layer to interior of pipe at critical erosion areas (Stellite® overlay1, boron diffusion layer, nitriding, etc.)\nTwo levels', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='Two levels\n1 Stellite is a federally registered trademark of Kennametal Inc.\nRelated Mechanisms\nIS 1: Sulfidation – Crude units, FCC units, and cokers can experience erosion-corrosion by sulfidation.', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='IS 6: Naphthenic Acid – Crude units experience erosion-corrosion by naphthenic acid.', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='IS 7: Ammonium Bisulfide – Carbon steel experiences erosion-corrosion by ammonium bisulfide at velocities > 20 fps (6 m/s). Turbulent areas are especially vulnerable.', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='IS 28: Cavitation – Impingement by gas bubbles causes erosion.\nReferences\n1. Inspection Requirements – Localized Thinning and Pitting – Piping.', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='2. API RP 571, Damage Mechanisms Affecting Fixed Equipment in the Refining Industry, 2nd ed. (April 2011).', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='3. Colangelo, V. J. and Heiser, F. A., Analysis of Metallurgical Failures, John Wiley & Sons, New York (1974).', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='4. Fontana, M. G. and Greene, N. D., Corrosion Engineering, McGraw-Hill Book Company, New York (1967).', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='5. Metals Handbook, Volume 10: Failure Analysis and Prevention, Harold E. Boyer, editor, American Society for Metals, Metals Park, Ohio, 8th ed. (1975).', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='6. Raghu, D., McKee, B., Sheriff, C., and Wu, J., “High Temperature Erosion Resistant Materials for Petroleum Refinery Equipment,” Publication 51300-01513-SG, NACE International, Houston, TX (2001).', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='7. Saidulu, G. et al, “Optimizing conditions, modifying design improve FCC regenerator,” Oil & Gas Journal, Houston, TX (Dec. 2010).\nImages and Charts', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='Images and Charts\n© 2015 – 2017 Chevron U.S.A. Inc. All rights reserved. Company Confidential – Uncontrolled When Printed\n10 of 14', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='10 of 14\nInspection Strategy 20: Erosion/Erosion-Corrosion Version 1.8, July 26, 2017\nDownstream & Chemicals – Manufacturing\nVersion History', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='Version History\nIS 20 on erosion/erosion-corrosion has been revised as indicated in the following table.\nVersion No. Change\nFrom\nTo\nDate\nSummary of Changes\nApproved by\n1.0\n1.1 Oct. 31, 2015', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='Approved by\n1.0\n1.1 Oct. 31, 2015\nSummary Page\nKelley Mobley\nAdded:\n\uf02d Version number.\n\uf02d Inspection methods.\n\uf02d Links to “Prevention and Mitigation” and “Version History”\nsections.\nSections Inspection', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='sections.\nSections Inspection\nAdded “Piping” and “Deadlegs” subsections.\nProbability of Failure (PoF)\nAdded PoF table to “Piping” subsection.\nReduction in Probability of Failure', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='Reduction in Probability of Failure\nAdded reduction table to “Piping” subsection.\nVersion History\nAdded as a new section.\n1.1\n1.2 May 24, 2016\nSummary Page\nKelley Mobley', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='1.1\n1.2 May 24, 2016\nSummary Page\nKelley Mobley\nChanged links and wording from:\n\uf02d Probability of Failure to Susceptibility to Damage.\n\uf02d Reduction in Probability to Reduction in Susceptibility.', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='Sections Inspection\nIn Item A:\n\uf02d Deleted in the following order from the first bullet.\n\uf02d Deleted sub-bullets to the second bullet, and added the\n“Feature Type/Inspection Focus” table.', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='“Feature Type/Inspection Focus” table.\nProbability of Failure (PoF)\nRenamed the section to “Susceptibility to Damage.”\nIn the “Piping” table:\n\uf02d Added an overarching Susceptibility Levels column', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='heading.\n\uf02d Removed Likely, Occasional, Seldom, Unlikely, Remote,\nand Rare from column headings.\n\uf02d Rows for corrosive process streams:\n▪ Changed Carbon steel with solids content > 1%,', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='▪ Changed Carbon steel with solids content > 1%,\nvelocity < 7 fps (2 m/s) to Carbon steel with solids content > 1%, 3 fps (1 m/s) ≤ velocity < 7 fps (2 m/s) in the Level 3 column.', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='▪ Changed CRA (300 series SS or Ni Cr alloys) with', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='solids content > 1%, velocity < 7 fps (2 m/s) to CRA (300 series SS or Ni Cr alloys) with solids content > 1%, 3 fps (1 m/s) ≤ velocity < 7 fps (2 m/s) in the Level', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='© 2015 – 2017 Chevron U.S.A. Inc. All rights reserved. Company Confidential – Uncontrolled When Printed\n11 of 14\nInspection Strategy 20: Erosion/Erosion-Corrosion Version 1.8, July 26, 2017', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='Downstream & Chemicals – Manufacturing\nVersion No. Change\nFrom\nTo\nDate\nSummary of Changes\nApproved by\n4 column.\n▪ Deleted all data in the Level 5 column.', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='▪ Deleted all data in the Level 5 column.\n\uf02d Changed velocity data from < 20 fps (9 m/s) to 10 fps (3 m/s) ≤ velocity < 20 fps (9 m/s) in the Level 5 column for noncorrosive streams.', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='\uf02d Renamed the row for high-velocity catalyst service to\nCatalyst Service Without Erosion-Resistant Refractory and revised all data except in the Level 1 cell (≥ 50 fps [15 m/s]).', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='\uf02d Deleted the table note Probability assessments are based', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='on a maximum time frame of 10 years and changed probability of to susceptibility to, and in the remaining note changed probability of failure to susceptibility level.', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='\uf02d Changed probability of failure assessment to when determining susceptibility level in the second table footnote.\nReduction in Probability of Failure', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='Reduction in Probability of Failure\nRenamed the section “Reduction in Susceptibility.”\nUnder “Piping”:', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='Under “Piping”:\n\uf02d Revised the table’s introductory statement from Probability of failure can be reduced... to Susceptibility level can be lowered...', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='\uf02d Revised the table’s right column heading from Probability\nReduction to Lower susceptibility by, and under the heading deleted all instances of Reduce.\n1.2\n1.3\nJune 29, 2016\nSections References', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='1.2\n1.3\nJune 29, 2016\nSections References\nKelley Mobley\nAdded link and reference to Inspection Requirements – Localized Thinning and Pitting – Piping.\n1.3\n1.4 Sept. 10, 2016 Summary Page\nKelley Mobley', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='1.3\n1.4 Sept. 10, 2016 Summary Page\nKelley Mobley\nAdded:\n\uf02d Business identifier heading.\n\uf02d Footer text on IS development and approval.\nSections Inspection', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='Sections Inspection\nIn the “Feature Type/Inspection Focus” table of Item A, deleted (e.g., a reducer immediately downstream of a control valve) from the footnote.\n1.4\n1.5 Oct. 21, 2016', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='1.4\n1.5 Oct. 21, 2016\nSections Inspection\nKelley Mobley', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='Sections Inspection\nKelley Mobley\nIn the second primary bullet of Item A, deleted including the outer and inner radius of all fittings after Inspect the full circumference of the components.', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='In the “Feature Type/Inspection Focus” table of Item A:\n\uf02d Changed three pipe diameters to 6 in. (15 cm) in the first bullet (on flow changes) in the Inspection Focus column of the Type A row.', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='© 2015 – 2017 Chevron U.S.A. Inc. All rights reserved. Company Confidential – Uncontrolled When Printed\n12 of 14\nInspection Strategy 20: Erosion/Erosion-Corrosion Version 1.8, July 26, 2017', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='Downstream & Chemicals – Manufacturing\nVersion No. Change\nFrom\nTo\nDate\nSummary of Changes\nApproved by', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='From\nTo\nDate\nSummary of Changes\nApproved by\n\uf02d Changed three pipe diameters to 6 in. (15 cm) in the first bullet (on flow changes) in the Inspection Focus column of the Type B row.\n1.5', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='1.5\n1.6 March 3, 2017\nSections Inspection\nKelley Mobley', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='In the second bullet of the Item A, changed Inspect the full circumference of the components... to Inspect the full circumference of piping components and areas up to 6 in. (15 cm) downstream...', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='In the Item A “Feature Type/Inspection Focus” table Type A Inspection Focus column:', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='\uf02d Revised the first primary bullet from At locations where flow changes direction up to 6 in. (15 cm) past the direction change, such as ells to At locations where flow changes direction, such as ells.', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='\uf02d Combined sub-bullets under the primary bullets “At areas of velocity increase, such as” and “At areas of increased turbulence, such as” in a single list under a new primary bullet, “Features immediately downstream of.”', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='\uf02d Revised the sub-bullet Control or flow-throttling valve\noutlets and bypasses to Control or flow-throttling valve outlets (including bypasses).', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='\uf02d Deleted the sub-bullet Thermowells (or other inserts).\n\uf02d Added the sub-bullet Internal protrusions.\n1.6', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='In the Item A “Feature Type/Inspection Focus” table Type B Inspection Focus column, changed the first primary bullet from At locations where flow changes direction up to 6 in. (15 cm) past the direction change, such as to At locations where flow changes, such as. Summary Page', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='In the Item A “Feature Type/Inspection Focus” table Type B Inspection Focus column, changed the first primary bullet from At locations where flow changes direction up to 6 in. (15 cm) past the direction change, such as to At locations where flow changes, such as. Summary Page', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='Kelley Mobley\nUnder “Inspection,” changed Close grid UT to Grid UT. Sections Inspection\nAdded the following section intro statement: Erosion/erosion- corrosion is categorized as localized corrosion.', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='In the first bullet of Item A:\n\uf02d Added the link for the profile radiographic testing\ninspection guide to Radiographic testing (RT) in the first sub-bullet.', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='\uf02d Added the link for the UT scanning inspection guide to\nscanning and the link for the UT grid inspection guide to grid in the second sub-bullet.', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='In the second bullet of Item A, deleted Use Inspection Guide: Piping – Localized Corrosion.\n1.7\n1.8\nJuly 26, 2017\nSections Inspection\nKelley Mobley\nUnder Item A:', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='Sections Inspection\nKelley Mobley\nUnder Item A:\n\uf02d Changed the second bullet item from Inspect the full\ncircumference of piping components and up to 6 inches', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='© 2015 – 2017 Chevron U.S.A. Inc. All rights reserved. Company Confidential – Uncontrolled When Printed\n13 of 14\nInspection Strategy 20: Erosion/Erosion-Corrosion Version 1.8, July 26, 2017', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='Downstream & Chemicals – Manufacturing\nVersion No. Change\nFrom\nTo\nDate\nSummary of Changes\nApproved by', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='From\nTo\nDate\nSummary of Changes\nApproved by\n(15 cm) downstream, focusing specifically on the features listed in the following table to Inspect the features listed in the following table.', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='\uf02d In the “Feature Type/Inspection Focus” table Feature', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='Type column, changed the Type B description from This feature type is also susceptible and should be included in inspection to This feature type is also susceptible due to high velocity or turbulence and should be included in inspection.', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='\uf02d In the “Feature Type/Inspection Focus” table Inspection\nFocus column: ▪ Changed the first bullet item in the Type A row from At', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='locations where flow changed directions, such as ells to At ells, including up to 6 in. (15 cm) downstream.', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='▪ Changed the first bullet item in the Type B row from At locations where flow changes such as to The following features, including up to 6 in. (15 cm) downstream; and added sub-bullets for Reducers and Expansion joints. ▪ Deleted the following bullet items in the Type B row: At areas of velocity increase, such as reducers; and At areas of increased turbulence, such as: Expansion joints, Areas of known excessive internal weld reinforcement.', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='▪ Changed Areas of known excessive internal weld\nreinforcement from a sub-bullet to a primary bullet in the Type B row.', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'}),
#  Document(page_content='© 2015 – 2017 Chevron U.S.A. Inc. All rights reserved. Company Confidential – Uncontrolled When Printed\n14 of 14', metadata={'source': '/Users/jun/FullStack_GPT/files/IS20_Erosion_ErosionCorrosion v1.8.pdf'})]
