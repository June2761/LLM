# %%
from langchain.chat_models import ChatOpenAI
from langchain.document_loaders import UnstructuredFileLoader
from langchain.text_splitter import CharacterTextSplitter
from langchain.embeddings import OpenAIEmbeddings, CacheBackedEmbeddings
from langchain.vectorstores import FAISS
from langchain.storage import LocalFileStore
from langchain.prompts import ChatPromptTemplate
from langchain.schema.runnable import RunnablePassthrough, RunnableLambda

llm = ChatOpenAI(
    temperature=0.1
)

cache_dir = LocalFileStore("../.cache/")

splitter = CharacterTextSplitter.from_tiktoken_encoder(
    separator="\n",
    chunk_size=600,
    chunk_overlap=100,
)
loader = UnstructuredFileLoader("../files/IS20_Erosion_ErosionCorrosion v1.8.pdf")

docs = loader.load_and_split(text_splitter=splitter)

embeddings = OpenAIEmbeddings()

cached_embeddings = CacheBackedEmbeddings.from_bytes_store(embeddings, cache_dir)

vectorstore = FAISS.from_documents(docs, cached_embeddings)

retrieval = vectorstore.as_retriever()

map_doc_prompt = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            """
            Use the following portion of a long document to see if any of the text is relevant to answer the question. Return any relevant text verbatim. If there is no relevant text, return : ''
            -------
            {context}
            """,
        ),
        ("human", "{question}"),
    ]
)

map_doc_chain = map_doc_prompt | llm

final_prompt = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            """
            Given the following extracted parts of a long document and a question, create a final answer. 
            If you don't know the answer, just say that you don't know. Don't try to make up an answer.
            ------
            {context}
            """,
        ),
        ("human", "{question}"),
    ]
)

def map_docs(inputs):
    documents = inputs['documents']
    question = inputs['question']
    return "\n\n".join(
        map_doc_chain.invoke(
            {"context":doc.page_content,"question":question}
        ).content
        for doc in documents
    )
#    for document in documents:
#        result = map_doc_chain.invoke({
#            "context":document.page_content, "question":question
#        }).contnet
#        results.appned(result)
#    results = "\n\n".join(results)
#    return results

map_chain = {
    "documents":retrieval,
    "question":RunnablePassthrough(),
} | RunnableLambda(map_docs)

chain = {
    "context":map_chain, 
    "question":RunnablePassthrough()
} | final_prompt | llm

chain.invoke("Describe the critical factor of erosion")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 23
#      16 splitter = CharacterTextSplitter.from_tiktoken_encoder(
#      17     separator="\n",
#      18     chunk_size=600,
#      19     chunk_overlap=100,
#      20 )
#      21 loader = UnstructuredFileLoader("../files/IS20_Erosion_ErosionCorrosion v1.8.pdf")
# ---> 23 docs = loader.load_and_split(text_splitter=splitter)
#      25 embeddings = OpenAIEmbeddings()
#      27 cached_embeddings = CacheBackedEmbeddings.from_bytes_store(embeddings, cache_dir)
#
# File ~/Agent/env/lib/python3.11/site-packages/langchain/document_loaders/base.py:43, in BaseLoader.load_and_split(self, text_splitter)
#      41 else:
#      42     _text_splitter = text_splitter
# ---> 43 docs = self.load()
#      44 return _text_splitter.split_documents(docs)
#
# File ~/Agent/env/lib/python3.11/site-packages/langchain/document_loaders/unstructured.py:86, in UnstructuredBaseLoader.load(self)
#      84 def load(self) -> List[Document]:
#      85     """Load file."""
# ---> 86     elements = self._get_elements()
#      87     self._post_process_elements(elements)
#      88     if self.mode == "elements":
#
# File ~/Agent/env/lib/python3.11/site-packages/langchain/document_loaders/unstructured.py:172, in UnstructuredFileLoader._get_elements(self)
#     169 def _get_elements(self) -> List:
#     170     from unstructured.partition.auto import partition
# --> 172     return partition(filename=self.file_path, **self.unstructured_kwargs)
#
# File ~/Agent/env/lib/python3.11/site-packages/unstructured/partition/auto.py:316, in partition(filename, content_type, file, file_filename, url, include_page_breaks, strategy, encoding, paragraph_grouper, headers, skip_infer_table_types, ssl_verify, ocr_languages, languages, pdf_infer_table_structure, xml_keep_tags, data_source_metadata, metadata_filename, **kwargs)
#     314 elif filetype == FileType.PDF:
#     315     _partition_pdf = _get_partition_with_extras("pdf")
# --> 316     elements = _partition_pdf(
#     317         filename=filename,  # type: ignore
#     318         file=file,  # type: ignore
#     319         url=None,
#     320         include_page_breaks=include_page_breaks,
#     321         infer_table_structure=infer_table_structure,
#     322         strategy=strategy,
#     323         languages=languages,
#     324         **kwargs,
#     325     )
#     326 elif (filetype == FileType.PNG) or (filetype == FileType.JPG) or (filetype == FileType.TIFF):
#     327     elements = partition_image(
#     328         filename=filename,  # type: ignore
#     329         file=file,  # type: ignore
#    (...)
#     335         **kwargs,
#     336     )
#
# File ~/Agent/env/lib/python3.11/site-packages/unstructured/documents/elements.py:244, in process_metadata.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     242 @functools.wraps(func)
#     243 def wrapper(*args, **kwargs):
# --> 244     elements = func(*args, **kwargs)
#     245     sig = inspect.signature(func)
#     246     params = dict(**dict(zip(sig.parameters, args)), **kwargs)
#
# File ~/Agent/env/lib/python3.11/site-packages/unstructured/file_utils/filetype.py:541, in add_metadata_with_filetype.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     539 @wraps(func)
#     540 def wrapper(*args, **kwargs):
# --> 541     elements = func(*args, **kwargs)
#     542     sig = inspect.signature(func)
#     543     params = dict(**dict(zip(sig.parameters, args)), **kwargs)
#
# File ~/Agent/env/lib/python3.11/site-packages/unstructured/chunking/title.py:197, in add_chunking_strategy.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     195 @wraps(func)
#     196 def wrapper(*args, **kwargs):
# --> 197     elements = func(*args, **kwargs)
#     198     sig = inspect.signature(func)
#     199     params = dict(**dict(zip(sig.parameters, args)), **kwargs)
#
# File ~/Agent/env/lib/python3.11/site-packages/unstructured/partition/pdf.py:130, in partition_pdf(filename, file, include_page_breaks, strategy, infer_table_structure, ocr_languages, languages, max_partition, min_partition, include_metadata, metadata_filename, metadata_last_modified, chunking_strategy, **kwargs)
#     124         languages = convert_old_ocr_languages_to_languages(ocr_languages)
#     125         logger.warning(
#     126             "The ocr_languages kwarg will be deprecated in a future version of unstructured. "
#     127             "Please use languages instead.",
#     128         )
# --> 130 return partition_pdf_or_image(
#     131     filename=filename,
#     132     file=file,
#     133     include_page_breaks=include_page_breaks,
#     134     strategy=strategy,
#     135     infer_table_structure=infer_table_structure,
#     136     languages=languages,
#     137     max_partition=max_partition,
#     138     min_partition=min_partition,
#     139     metadata_last_modified=metadata_last_modified,
#     140     **kwargs,
#     141 )
#
# File ~/Agent/env/lib/python3.11/site-packages/unstructured/partition/pdf.py:209, in partition_pdf_or_image(filename, file, is_image, include_page_breaks, strategy, infer_table_structure, ocr_languages, languages, max_partition, min_partition, metadata_last_modified, **kwargs)
#     203         languages = convert_old_ocr_languages_to_languages(ocr_languages)
#     204         logger.warning(
#     205             "The ocr_languages kwarg will be deprecated in a future version of unstructured. "
#     206             "Please use languages instead.",
#     207         )
# --> 209 last_modification_date = get_the_last_modification_date_pdf_or_img(
#     210     file=file,
#     211     filename=filename,
#     212 )
#     214 if (
#     215     not is_image
#     216     and determine_pdf_or_image_strategy(
#    (...)
#     223     != "ocr_only"
#     224 ):
#     225     extracted_elements = extractable_elements(
#     226         filename=filename,
#     227         file=spooled_to_bytes_io_if_needed(file),
#    (...)
#     230         **kwargs,
#     231     )
#
# File ~/Agent/env/lib/python3.11/site-packages/unstructured/partition/pdf.py:166, in get_the_last_modification_date_pdf_or_img(file, filename)
#     164 last_modification_date = None
#     165 if not file and filename:
# --> 166     last_modification_date = get_last_modified_date(filename=filename)
#     167 elif not filename and file:
#     168     last_modification_date = get_last_modified_date_from_file(file=file)
#
# File ~/Agent/env/lib/python3.11/site-packages/unstructured/partition/common.py:81, in get_last_modified_date(filename)
#      80 def get_last_modified_date(filename: str) -> Union[str, None]:
# ---> 81     modify_date = datetime.fromtimestamp(os.path.getmtime(filename))
#      82     return modify_date.strftime("%Y-%m-%dT%H:%M:%S%z")
#
# File <frozen genericpath>:55, in getmtime(filename)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../files/IS20_Erosion_ErosionCorrosion v1.8.pdf'
